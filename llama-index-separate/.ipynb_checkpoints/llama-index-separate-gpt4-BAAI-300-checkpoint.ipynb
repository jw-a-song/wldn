# %% [markdown]
# RETRIEVER

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader,get_response_synthesizer
from llama_index.core import SimpleDirectoryReader
from llama_index.core import Settings

Settings.chunk_size = 300
Settings.chunk_overlap = 80

documents = SimpleDirectoryReader("/mnt/disk1/sjw/llama_index/data").load_data()
index = VectorStoreIndex.from_documents(documents)
retriever = index.as_retriever(verbose=True, similarity_top_k=3)

# %%
eval_q_data = SimpleDirectoryReader("/mnt/disk1/sjw/llama_index/eval-q").load_data()

# %%
q_data = eval_q_data[0].text

questions = [line.strip().strip('"') for line in q_data.split('\n') if line.strip()]

# %%
retriever_result = {}
search_results = []

for count, question in enumerate(questions, start=1):
    search_this = f"{question}"
    search_result = retriever.retrieve(search_this)
    search_results = []
    
    for i in range(retriever.similarity_top_k):
        search_results.append(search_result[i].get_text())

    retriever_result[count] = search_results

# %% [markdown]
# EMBEDDING MODEL

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings

Settings.embed_model = HuggingFaceEmbedding(
    model_name="BAAI/bge-small-en-v1.5"
)

# %% [markdown]
# VECTOR STORE

# %%
from llama_index.core import VectorStoreIndex

vector_index = VectorStoreIndex.from_documents(documents)

# %% [markdown]
# GENERATOR

# %%
responses=[]

# %%
from llama_index.llms.openai import OpenAI
from openai import ChatCompletion
from llama_index.core.llms import ChatMessage

llm = OpenAI(model="gpt-4")
Settings.llm = llm

# %%
for count, question in enumerate(questions, start=1):
    retriever_context_list = retriever_result.get(count, [])
    retriever_context = ' '.join(retriever_context_list)
    
    query = f"Given the context: '{retriever_context}', determine if the following statement is 'True' or 'False': {question}. Start your response with 'True' or 'False'. Answer:"
    messages = [
    ChatMessage(
        role="system", content="You are a helpful assisant"),
    ChatMessage(role="user", content=query),
    ]
    response = llm.chat(messages)

    # Find the position of "Answer:" and extract the response
    #aa = response_text.find("Answer:")
    #if aa != -1:
     #   response = response_text[aa + 7:].strip().split()[0]  # Extract the first word after "Answer:"

    responses.append(response)

    print(count, response)
# Out:
# 1 assistant: True
# 2 assistant: False
# 3 assistant: True
# 4 assistant: False
# 5 assistant: True
# 6 assistant: True
# 7 assistant: True
# 8 assistant: True
# 9 assistant: False
# 10 assistant: False
# 11 assistant: False
# 12 assistant: True
# 13 assistant: False
# 14 assistant: True
# 15 assistant: False
# 16 assistant: True
# 17 assistant: False
# 18 assistant: False
# 19 assistant: False
# 20 assistant: True
# 21 assistant: False
# 22 assistant: True
# 23 assistant: False
# 24 assistant: False
# 25 assistant: True
# 26 assistant: False
# 27 assistant: True
# 28 assistant: False
# 29 assistant: True
# 30 assistant: True
# 31 assistant: False
# 32 assistant: True
# 33 assistant: True
# 34 assistant: False
# 35 assistant: True
# 36 assistant: True
# 37 assistant: False
# 38 assistant: False
# 39 assistant: True
# 40 assistant: False
# 41 assistant: True
# 42 assistant: False
# 43 assistant: False
# 44 assistant: True
# 45 assistant: True
# 46 assistant: False
# 47 assistant: True
# 48 assistant: False
# 49 assistant: True
# 50 assistant: False
# 51 assistant: True
# 52 assistant: False
# 53 assistant: False
# 54 assistant: True
# 55 assistant: True
# 56 assistant: True
# 57 assistant: False
# 58 assistant: True
# 59 assistant: False
# 60 assistant: False
# 61 assistant: True
# 62 assistant: True
# 63 assistant: False
# 64 assistant: True
# 65 assistant: True
# 66 assistant: True
# 67 assistant: True
# 68 assistant: True
# 69 assistant: False
# 70 assistant: False
# 71 assistant: False
# 72 assistant: True
# 73 assistant: True
# 74 assistant: True
# 75 assistant: False
# 76 assistant: True
# 77 assistant: False
# 78 assistant: False
# 79 assistant: True
# 80 assistant: False
# 81 assistant: True
# 82 assistant: False
# 83 assistant: False. The text does not provide information on why Arietta can sing in multiple languages.
# 84 assistant: False
# 85 assistant: True
# 86 assistant: True
# 87 assistant: The text does not provide information on whether scientists were initially skeptical about the reports of Arietta’s singing abilities, dismissing them as local folklore.
# 88 assistant: False
# 89 assistant: True
# 90 assistant: False
# 91 assistant: False
# 92 assistant: True
# 93 assistant: False
# 94 assistant: True
# 95 assistant: False
# 96 assistant: False
# 97 assistant: True
# 98 assistant: False: The text does not provide information on the effect of Arietta’s songs on the local wildlife around Pinewood Lake.
# 99 assistant: False
# 100 assistant: False
# 101 assistant: False
# 102 assistant: True
# 103 assistant: False. The text does not provide any information about Dr. Evelyn Tran’s theory about multiple dimensions or its acceptance by the scientific community.
# 104 assistant: False
# 105 assistant: False
# 106 assistant: False
# 107 assistant: False
# 108 assistant: False
# 109 assistant: True
# 110 assistant: False
# 111 assistant: True
# 112 assistant: False
# 113 assistant: False
# 114 assistant: False
# 115 assistant: False
# 116 assistant: True
# 117 assistant: False
# 118 assistant: True
# 119 assistant: True
# 120 assistant: False
# 121 assistant: False
# 122 assistant: True
# 123 assistant: False
# 124 assistant: True
# 125 assistant: True
# 126 assistant: False
# 127 assistant: True
# 128 assistant: True
# 129 assistant: True
# 130 assistant: False: The text does not provide any information about experiments conducted by scientists in Pinewood Hills or their results.
# 131 assistant: True
# 132 assistant: True
# 133 assistant: True
# 134 assistant: False
# 135 assistant: False
# 136 assistant: False. The text does not provide information on local artists in Pinewood Hills creating works inspired by Whiskers and Arietta.
# 137 assistant: False
# 138 assistant: False
# 139 assistant: False
# 140 assistant: True
# 141 assistant: True
# 142 assistant: False
# 143 assistant: False
# 144 assistant: False
# 145 assistant: False
# 146 assistant: False
# 147 assistant: False
# 148 assistant: True
# 149 assistant: False
# 150 assistant: False
# 151 assistant: False. The text does not mention a Dr. Sarah Levine or any theories about Arietta's singing abilities being a result of an unknown genetic mutation.
# 152 assistant: False
# 153 assistant: False
# 154 assistant: False
# 155 assistant: False
# 156 assistant: True
# 157 assistant: False
# 158 assistant: False
# 159 assistant: True
# 160 assistant: False
# 161 assistant: False
# 162 assistant: False
# 163 assistant: True
# 164 assistant: False
# 165 assistant: False
# 166 assistant: False
# 167 assistant: False
# 168 assistant: False
# 169 assistant: False
# 170 assistant: False
# 171 assistant: False
# 172 assistant: False
# 173 assistant: False
# 174 assistant: False
# 175 assistant: False. The text does not provide information on whether Arietta's singing had a soothing effect on anyone who listened, even from a distance.
# 176 assistant: True
# 177 assistant: True
# 178 assistant: True
# 179 assistant: False
# 180 assistant: True
# 181 assistant: True
# 182 assistant: False
# 183 assistant: False
# 184 assistant: False
# 185 assistant: True
# 186 assistant: False
# 187 assistant: False
# 188 assistant: False
# 189 assistant: False
# 190 assistant: True
# 191 assistant: False
# 192 assistant: True
# 193 assistant: False
# 194 assistant: False
# 195 assistant: False
# 196 assistant: False
# 197 assistant: True
# 198 assistant: False
# 199 assistant: True
# 200 assistant: False

# %% [markdown]
# EVALUATOR

# %%
eval_a_data = SimpleDirectoryReader("/mnt/disk1/sjw/llama_index/eval-a").load_data()

# %%
a_data = eval_a_data[0].text

answers = [line.strip().strip('"') for line in a_data.split('\n') if line.strip()]

# %%
responses_str = []

# %%
for response in responses:
    response_str = str(response)
    if "True" in response_str:
        response_str = "True"
    elif "False" in response_str:
        response_str = "False"
    
    responses_str.append(response_str)

# %%
correct_count=0
number=0

for answer, response, response_str, question in zip(answers, responses, responses_str, questions,):
    number+=1

    if answer == response_str:
        correct_count += 1
    else: 
        print("<<wrong>>\n", number, question)
        print("RESPONSE", response)
        print("CORRECT ANSWER", answer)
        print()
print(f"correct_count: {correct_count}")
# Out:
# <<wrong>>
#  10 True or False: The discovery of exotic matter with negative mass is a direct result of fourth-dimensional research.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  18 True or False: The ability of marine life to adapt smoothly to a liquid atmosphere is due to their existing aquatic adaptations.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  23 True or False: Human genetic modifications are necessary for extracting oxygen from a liquid atmosphere due to fourth-dimensional advancements.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  63 True or False: Discovering a fourth spatial dimension resulted in creating technologies for a liquid breathable atmosphere.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  69 True or False: Discoveries in fourth-dimensional technology have altered global political power structures.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  70 True or False: Researchers have successfully altered atomic bonds to convert gases into a breathable liquid.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  74 True or False: The space station derives its energy from the neutron star using advanced fusion technology.
# RESPONSE assistant: True
# CORRECT ANSWER False
#
# <<wrong>>
#  75 True or False: Discoveries in fourth-dimensional technology have altered global political power structures.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  78 True or False: Whiskers’ ability to pass through walls was first observed after the Johnsons moved into their Victorian home.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  84 True or False: Whiskers was responsible for the first occurrence of a time loop in Pinewood Hills.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  87 True or False: Scientists were initially skeptical about the reports of Arietta’s singing abilities, dismissing them as local folklore.
# RESPONSE assistant: The text does not provide information on whether scientists were initially skeptical about the reports of Arietta’s singing abilities, dismissing them as local folklore.
# CORRECT ANSWER False
#
# <<wrong>>
#  95 True or False: The mysterious abilities of Whiskers and Arietta led to the formation of a special research team in Pinewood Hills.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  136 True or False: Local artists in Pinewood Hills created works inspired by Whiskers and Arietta.
# RESPONSE assistant: False. The text does not provide information on local artists in Pinewood Hills creating works inspired by Whiskers and Arietta.
# CORRECT ANSWER True
#
# <<wrong>>
#  145 True or False: Arietta’s singing could be heard across the frozen waters of Pinewood Lake during the time loop incident.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  149 True or False: Whiskers was known to interact with other ghostly animals in Pinewood Hills.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  158 True or False: The Watson family initially tried to keep Arietta a secret from the public.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  162 True or False: Pinewood Hills had to expand its infrastructure to accommodate the increased number of visitors.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  164 True or False: Whiskers once disappeared for an entire day, leaving the Johnson family very worried.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  166 True or False: Dr. Martin Graves speculated that Whiskers might be a projection from another dimension.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  172 True or False: Dr. Evelyn Tran suggested that Whiskers and Arietta might be connected through a quantum entanglement.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  175 True or False: Arietta's singing had a soothing effect on anyone who listened, even from a distance.
# RESPONSE assistant: False. The text does not provide information on whether Arietta's singing had a soothing effect on anyone who listened, even from a distance.
# CORRECT ANSWER True
#
# <<wrong>>
#  185 True or False: The Pinewood Hills Institute for Extraordinary Phenomena was established primarily to study paranormal activity.
# RESPONSE assistant: True
# CORRECT ANSWER False
#
# <<wrong>>
#  189 True or False: The fourth-dimensional technology could potentially allow scientists to manipulate time as well as space.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  193 True or False: The discovery of a fourth spatial dimension has led to new artistic movements and expressions.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# <<wrong>>
#  195 True or False: Arietta's songs were believed to have the power to calm storms around Pinewood Lake.
# RESPONSE assistant: False
# CORRECT ANSWER True
#
# correct_count: 175

# %%
accuracy = (correct_count / len(questions)) * 100
print(f"Total Questions: {len(questions)}")
print(f"Correct Answers: {correct_count}")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# Total Questions: 200
# Correct Answers: 175
# Accuracy: 87.50%

# %%
Settings
# Out:
# _Settings(_llm=OpenAI(callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x79b07db3ae00>, system_prompt=None, messages_to_prompt=<function messages_to_prompt at 0x79b08be01120>, completion_to_prompt=<function default_completion_to_prompt at 0x79b08bead3f0>, output_parser=None, pydantic_program_mode=<PydanticProgramMode.DEFAULT: 'default'>, query_wrapper_prompt=None, model='gpt-4', temperature=0.1, max_tokens=None, logprobs=None, top_logprobs=0, additional_kwargs={}, max_retries=3, timeout=60.0, default_headers=None, reuse_client=True, api_key='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', api_base='https://api.openai.com/v1', api_version='', strict=False), _embed_model=HuggingFaceEmbedding(model_name='BAAI/bge-small-en-v1.5', embed_batch_size=10, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x79b07db3ae00>, num_workers=None, max_length=512, normalize=True, query_instruction=None, text_instruction=None, cache_folder=None), _callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x79b07db3ae00>, _tokenizer=None, _node_parser=SentenceSplitter(include_metadata=True, include_prev_next_rel=True, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x79b07db3ae00>, id_func=<function default_id_func at 0x79b08bede710>, chunk_size=300, chunk_overlap=80, separator=' ', paragraph_separator='\n\n\n', secondary_chunking_regex='[^,.;。？！]+[,.;。？！]?'), _prompt_helper=None, _transformations=[SentenceSplitter(include_metadata=True, include_prev_next_rel=True, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x79b07db3ae00>, id_func=<function default_id_func at 0x79b08bede710>, chunk_size=300, chunk_overlap=80, separator=' ', paragraph_separator='\n\n\n', secondary_chunking_regex='[^,.;。？！]+[,.;。？！]?')])

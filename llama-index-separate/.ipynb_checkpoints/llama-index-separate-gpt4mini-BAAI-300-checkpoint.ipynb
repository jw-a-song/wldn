# %% [markdown]
# RETRIEVER

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader,get_response_synthesizer
from llama_index.core import SimpleDirectoryReader
from llama_index.core import Settings

Settings.chunk_size = 300
Settings.chunk_overlap = 80

documents = SimpleDirectoryReader("/mnt/disk1/sjw/llama_index/data").load_data()
index = VectorStoreIndex.from_documents(documents)
retriever = index.as_retriever(verbose=True, similarity_top_k=2)
response_synthesizer = get_response_synthesizer(
    response_mode="compact",
)
query_engine = index.as_query_engine()

# %%
eval_q_data = SimpleDirectoryReader("/mnt/disk1/sjw/llama_index/eval-q").load_data()

# %%
q_data = eval_q_data[0].text

questions = [line.strip().strip('"') for line in q_data.split('\n') if line.strip()]

# %%
retriever_result = {}
search_results = []

for count, question in enumerate(questions, start=1):
    search_this = f"{question}"
    search_result = retriever.retrieve(search_this)
    search_results = []
    
    for i in range(retriever.similarity_top_k):
        search_results.append(search_result[i].get_text())

    retriever_result[count] = search_results
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-389784c40557> in <module>
#       4 for count, question in enumerate(questions, start=1):
#       5     search_this = f"{question}"
# ----> 6     search_result = retriever.retrieve(search_this)
#       7     search_results = []
#       8
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     258             )
#     259             try:
# --> 260                 result = func(*args, **kwargs)
#     261             except BaseException as e:
#     262                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/llama_index/core/base/base_retriever.py in retrieve(self, str_or_query_bundle)
#     241                 payload={EventPayload.QUERY_STR: query_bundle.query_str},
#     242             ) as retrieve_event:
# --> 243                 nodes = self._retrieve(query_bundle)
#     244                 nodes = self._handle_recursive_retrieval(query_bundle, nodes)
#     245                 retrieve_event.on_end(
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     258             )
#     259             try:
# --> 260                 result = func(*args, **kwargs)
#     261             except BaseException as e:
#     262                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/llama_index/core/indices/vector_store/retrievers/retriever.py in _retrieve(self, query_bundle)
#      95             if query_bundle.embedding is None and len(query_bundle.embedding_strs) > 0:
#      96                 query_bundle.embedding = (
# ---> 97                     self._embed_model.get_agg_embedding_from_queries(
#      98                         query_bundle.embedding_strs
#      99                     )
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/llama_index/core/base/embeddings/base.py in get_agg_embedding_from_queries(self, queries, agg_fn)
#     182     ) -> Embedding:
#     183         """Get aggregated embedding from multiple queries."""
# --> 184         query_embeddings = [self.get_query_embedding(query) for query in queries]
#     185         agg_fn = agg_fn or mean_agg
#     186         return agg_fn(query_embeddings)
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/llama_index/core/base/embeddings/base.py in <listcomp>(.0)
#     182     ) -> Embedding:
#     183         """Get aggregated embedding from multiple queries."""
# --> 184         query_embeddings = [self.get_query_embedding(query) for query in queries]
#     185         agg_fn = agg_fn or mean_agg
#     186         return agg_fn(query_embeddings)
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     258             )
#     259             try:
# --> 260                 result = func(*args, **kwargs)
#     261             except BaseException as e:
#     262                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/llama_index/core/base/embeddings/base.py in get_query_embedding(self, query)
#     131             CBEventType.EMBEDDING, payload={EventPayload.SERIALIZED: self.to_dict()}
#     132         ) as event:
# --> 133             query_embedding = self._get_query_embedding(query)
#     134
#     135             event.on_end(
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/llama_index/core/instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     258             )
#     259             try:
# --> 260                 result = func(*args, **kwargs)
#     261             except BaseException as e:
#     262                 self.event(SpanDropEvent(span_id=id_, err_str=str(e)))
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/llama_index/embeddings/openai/base.py in _get_query_embedding(self, query)
#     385         """Get query embedding."""
#     386         client = self._get_client()
# --> 387         return get_embedding(
#     388             client,
#     389             query,
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     334             copy = self.copy()
#     335             wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 336             return copy(f, *args, **kw)
#     337
#     338         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     473         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     474         while True:
# --> 475             do = self.iter(retry_state=retry_state)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/tenacity/__init__.py in iter(self, retry_state)
#     374         result = None
#     375         for action in self.iter_state.actions:
# --> 376             result = action(retry_state)
#     377         return result
#     378
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/tenacity/__init__.py in <lambda>(rs)
#     396     def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     397         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 398             self._add_action_func(lambda rs: rs.outcome.result())
#     399             return
#     400
#
# ~/anaconda3/envs/torch2/lib/python3.10/concurrent/futures/_base.py in result(self, timeout)
#     449                     raise CancelledError()
#     450                 elif self._state == FINISHED:
# --> 451                     return self.__get_result()
#     452
#     453                 self._condition.wait(timeout)
#
# ~/anaconda3/envs/torch2/lib/python3.10/concurrent/futures/_base.py in __get_result(self)
#     401         if self._exception:
#     402             try:
# --> 403                 raise self._exception
#     404             finally:
#     405                 # Break a reference cycle with the exception in self._exception
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     476             if isinstance(do, DoAttempt):
#     477                 try:
# --> 478                     result = fn(*args, **kwargs)
#     479                 except BaseException:  # noqa: B902
#     480                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/llama_index/embeddings/openai/base.py in get_embedding(client, text, engine, **kwargs)
#     135
#     136     return (
# --> 137         client.embeddings.create(input=[text], model=engine, **kwargs).data[0].embedding
#     138     )
#     139
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/openai/resources/embeddings.py in create(self, input, model, dimensions, encoding_format, user, extra_headers, extra_query, extra_body, timeout)
#     112             return obj
#     113
# --> 114         return self._post(
#     115             "/embeddings",
#     116             body=maybe_transform(params, embedding_create_params.EmbeddingCreateParams),
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1257             method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258         )
# -> 1259         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1260
#    1261     def patch(
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/openai/_base_client.py in request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     934         stream_cls: type[_StreamT] | None = None,
#     935     ) -> ResponseT | _StreamT:
# --> 936         return self._request(
#     937             cast_to=cast_to,
#     938             options=options,
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/openai/_base_client.py in _request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     970
#     971         try:
# --> 972             response = self._client.send(
#     973                 request,
#     974                 stream=stream or self._should_stream_response_body(request=request),
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     926         except BaseException as exc:
#     927             response.close()
# --> 928             raise exc
#     929
#     930     def _send_handling_auth(
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     920         try:
#     921             if not stream:
# --> 922                 response.read()
#     923
#     924             return response
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/httpx/_models.py in read(self)
#     811         """
#     812         if not hasattr(self, "_content"):
# --> 813             self._content = b"".join(self.iter_bytes())
#     814         return self._content
#     815
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/httpx/_models.py in iter_bytes(self, chunk_size)
#     827             chunker = ByteChunker(chunk_size=chunk_size)
#     828             with request_context(request=self._request):
# --> 829                 for raw_bytes in self.iter_raw():
#     830                     decoded = decoder.decode(raw_bytes)
#     831                     for chunk in chunker.decode(decoded):
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/httpx/_models.py in iter_raw(self, chunk_size)
#     881
#     882         with request_context(request=self._request):
# --> 883             for raw_stream_bytes in self.stream:
#     884                 self._num_bytes_downloaded += len(raw_stream_bytes)
#     885                 for chunk in chunker.decode(raw_stream_bytes):
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/httpx/_client.py in __iter__(self)
#     124
#     125     def __iter__(self) -> typing.Iterator[bytes]:
# --> 126         for chunk in self._stream:
#     127             yield chunk
#     128
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/httpx/_transports/default.py in __iter__(self)
#     111     def __iter__(self) -> typing.Iterator[bytes]:
#     112         with map_httpcore_exceptions():
# --> 113             for part in self._httpcore_stream:
#     114                 yield part
#     115
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py in __iter__(self)
#     365         except BaseException as exc:
#     366             self.close()
# --> 367             raise exc from None
#     368
#     369     def close(self) -> None:
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py in __iter__(self)
#     361     def __iter__(self) -> Iterator[bytes]:
#     362         try:
# --> 363             for part in self._stream:
#     364                 yield part
#     365         except BaseException as exc:
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/httpcore/_sync/http11.py in __iter__(self)
#     347             with ShieldCancellation():
#     348                 self.close()
# --> 349             raise exc
#     350
#     351     def close(self) -> None:
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/httpcore/_sync/http11.py in __iter__(self)
#     339         try:
#     340             with Trace("receive_response_body", logger, self._request, kwargs):
# --> 341                 for chunk in self._connection._receive_response_body(**kwargs):
#     342                     yield chunk
#     343         except BaseException as exc:
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/httpcore/_sync/http11.py in _receive_response_body(self, request)
#     208
#     209         while True:
# --> 210             event = self._receive_event(timeout=timeout)
#     211             if isinstance(event, h11.Data):
#     212                 yield bytes(event.data)
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     222
#     223             if event is h11.NEED_DATA:
# --> 224                 data = self._network_stream.read(
#     225                     self.READ_NUM_BYTES, timeout=timeout
#     226                 )
#
# ~/anaconda3/envs/torch2/lib/python3.10/site-packages/httpcore/_backends/sync.py in read(self, max_bytes, timeout)
#     124         with map_exceptions(exc_map):
#     125             self._sock.settimeout(timeout)
# --> 126             return self._sock.recv(max_bytes)
#     127
#     128     def write(self, buffer: bytes, timeout: typing.Optional[float] = None) -> None:
#
# ~/anaconda3/envs/torch2/lib/python3.10/ssl.py in recv(self, buflen, flags)
#    1257                     "non-zero flags not allowed in calls to recv() on %s" %
#    1258                     self.__class__)
# -> 1259             return self.read(buflen)
#    1260         else:
#    1261             return super().recv(buflen, flags)
#
# ~/anaconda3/envs/torch2/lib/python3.10/ssl.py in read(self, len, buffer)
#    1130                 return self._sslobj.read(len, buffer)
#    1131             else:
# -> 1132                 return self._sslobj.read(len)
#    1133         except SSLError as x:
#    1134             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %% [markdown]
# EMBEDDING MODEL

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings

Settings.embed_model = HuggingFaceEmbedding(
    model_name="BAAI/bge-small-en-v1.5"
)

# %% [markdown]
# VECTOR STORE

# %%
from llama_index.core import VectorStoreIndex

vector_index = VectorStoreIndex.from_documents(documents)

# %% [markdown]
# GENERATOR

# %%
responses=[]

# %%
from llama_index.llms.openai import OpenAI
from openai import ChatCompletion
from llama_index.core.llms import ChatMessage

llm = OpenAI(model="gpt-4o-mini")
Settings.llm=llm

# %%
for count, question in enumerate(questions, start=1):
    retriever_context_list = retriever_result.get(count, [])
    retriever_context = ' '.join(retriever_context_list)
    
    query = f"Given the context: '{retriever_context}', determine if the following statement is 'True' or 'False': {question}. Start your response with 'True' or 'False'. Answer:"
    messages = [
    ChatMessage(
        role="system", content="You are a helpful assisant"
    ),
    ChatMessage(role="user", content=query),
    ]
    response = llm.chat(messages)

    response_text = response.text if hasattr(response, 'text') else str(response)

    # Find the position of "Answer:" and extract the response
    #aa = response_text.find("Answer:")
    #if aa != -1:
     #   response = response_text[aa + 7:].strip().split()[0]  # Extract the first word after "Answer:"

    responses.append(response)

    print(count, response)

# %% [markdown]
# EVALUATOR

# %%
eval_a_data = SimpleDirectoryReader("/mnt/disk1/sjw/llama_index/eval-a").load_data()

# %%
a_data = eval_a_data[0].text

answers = [line.strip().strip('"') for line in a_data.split('\n') if line.strip()]

# %%
responses_str = []

# %%
for response in responses:
    response_str = str(response)
    if "True" in response_str:
        response_str = "True"
    elif "False" in response_str:
        response_str = "False"
    
    responses_str.append(response_str)

# %%
correct_count=0
number=0

for answer, response, response_str, question in zip(answers, responses, responses_str, questions,):
    number+=1

    if answer == response_str:
        correct_count += 1
    else: 
        print("<<wrong>>\n", number, question)
        print("RESPONSE", response)
        print("CORRECT ANSWER", answer)
        print()
print(f"correct_count: {correct_count}")

# %%
accuracy = (correct_count / len(questions)) * 100
print(f"Total Questions: {len(questions)}")
print(f"Correct Answers: {correct_count}")
print(f"Accuracy: {accuracy:.2f}%")

# %%
Settings

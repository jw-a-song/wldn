# %% [markdown]
# RETRIEVER

# %%
pip install llama-index-embeddings-openai
# Out:
# Requirement already satisfied: llama-index-embeddings-openai in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (0.1.11)
# Requirement already satisfied: llama-index-core<0.11.0,>=0.10.1 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-embeddings-openai) (0.10.62)
# Requirement already satisfied: deprecated>=1.2.9.3 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.2.14)
# Requirement already satisfied: pandas in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.1.0)
# Requirement already satisfied: pillow>=9.0.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (10.4.0)
# Requirement already satisfied: PyYAML>=6.0.1 in /home/jjh_test/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (6.0.1)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.12.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (8.5.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.1 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.66.5)
# Requirement already satisfied: wrapt in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.12.1)
# Requirement already satisfied: numpy<2.0.0 in /home/jjh_test/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.26.4)
# Requirement already satisfied: openai>=1.1.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.40.6)
# Requirement already satisfied: SQLAlchemy[asyncio]>=1.4.49 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.0.31)
# Requirement already satisfied: fsspec>=2023.5.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.3.1)
# Requirement already satisfied: typing-inspect>=0.8.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.9.0)
# Requirement already satisfied: networkx>=3.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.9.5)
# Requirement already satisfied: nltk<4.0.0,>=3.8.1 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.8.1)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.8)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.6.0)
# Requirement already satisfied: dataclasses-json in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.6.7)
# Requirement already satisfied: httpx in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.27.0)
# Requirement already satisfied: requests>=2.31.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.32.3)
# Requirement already satisfied: tiktoken>=0.3.3 in /home/jjh_test/.local/lib/python3.10/site-packages (from llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.7.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.9.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (23.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (6.0.5)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.4.1)
# Requirement already satisfied: joblib in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.4.16)
# Requirement already satisfied: click in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from nltk<4.0.0,>=3.8.1->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (8.1.7)
# Requirement already satisfied: sniffio in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.3.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/jjh_test/.local/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.9.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (4.4.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.8.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.5.0)
# Requirement already satisfied: httpcore==1.* in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.5)
# Requirement already satisfied: certifi in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2024.7.4)
# Requirement already satisfied: idna in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.4)
# Requirement already satisfied: h11<0.15,>=0.13 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from httpcore==1.*->httpx->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.14.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from requests>=2.31.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.0.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from typing-inspect>=0.8.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (3.21.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/jjh_test/.local/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2023.3)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from anyio<5,>=3.5.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.2.1)
# Requirement already satisfied: packaging>=17.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (24.1)
# Requirement already satisfied: pydantic-core==2.20.1 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (2.20.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from pydantic<3,>=1.9.0->openai>=1.1.0->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/jjh_test/anaconda3/envs/torch2/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->llama-index-core<0.11.0,>=0.10.1->llama-index-embeddings-openai) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader,get_response_synthesizer
from llama_index.core import SimpleDirectoryReader
from llama_index.core import Settings

Settings.chunk_size = 128
Settings.chunk_overlap = 50

documents = SimpleDirectoryReader("/mnt/disk1/sjw/llama_index/data").load_data()
index = VectorStoreIndex.from_documents(documents)
retriever = index.as_retriever(verbose=True, similarity_top_k=2)
response_synthesizer = get_response_synthesizer(
    response_mode="compact",
)
query_engine = index.as_query_engine()

# %%
eval_q_data = SimpleDirectoryReader("/mnt/disk1/sjw/llama_index/eval-q").load_data()

# %%
q_data = eval_q_data[0].text

questions = [line.strip().strip('"') for line in q_data.split('\n') if line.strip()]

# %%
retriever_result = {}
search_results = []

for count, question in enumerate(questions, start=1):
    search_this = f"{question}"
    search_result = retriever.retrieve(search_this)
    search_results = []
    
    for i in range(retriever.similarity_top_k):
        search_results.append(search_result[i].get_text())

    retriever_result[count] = search_results

# %% [markdown]
# EMBEDDING MODEL

# %% [raw]
# from llama_index.embeddings.huggingface import HuggingFaceEmbedding
# from llama_index.core import Settings
#
# Settings.embed_model = HuggingFaceEmbedding(
#     model_name="BAAI/bge-small-en-v1.5"
# )

# %% [markdown]
# GENERATOR

# %%
from llama_index.core import VectorStoreIndex

vector_index = VectorStoreIndex.from_documents(documents)

# %%
responses=[]

# %%
for count, question in enumerate(questions, start=1):
    retriever_context_list = retriever_result.get(count, [])
    retriever_context = ' '.join(retriever_context_list)
    
    query = f"Given the context: '{retriever_context}', determine if the following statement is 'True' or 'False': {question}. Start your response with 'True' or 'False'. Answer:"

    # It's better to create the query engine once outside the loop if it doesn't need to be recreated each time
    query_engine = index.as_query_engine()
    response = query_engine.query(query)

    # Assuming response has a 'text' attribute that contains the response as a string
    response_text = response.text if hasattr(response, 'text') else str(response)

    # Find the position of "Answer:" and extract the response
    #aa = response_text.find("Answer:")
    #if aa != -1:
     #   response = response_text[aa + 7:].strip().split()[0]  # Extract the first word after "Answer:"

    responses.append(response)

    print(count, response)
# Out:
# 1 True
# 2 False.
# 3 True
# 4 False.
# 5 True
# 6 True
# 7 False
# 8 True
# 9 False
# 10 False.
# 11 False
# 12 True
# 13 False
# 14 True
# 15 False
# 16 True
# 17 False
# 18 True
# 19 False
# 20 True
# 21 False.
# 22 True
# 23 False
# 24 False.
# 25 True
# 26 False.
# 27 True
# 28 False.
# 29 True
# 30 True
# 31 False.
# 32 True
# 33 True
# 34 False.
# 35 True
# 36 True
# 37 True
# 38 False.
# 39 True
# 40 False
# 41 True
# 42 False
# 43 False
# 44 True
# 45 True
# 46 False
# 47 True
# 48 False
# 49 True
# 50 False
# 51 True
# 52 False.
# 53 False
# 54 True
# 55 True
# 56 True
# 57 False.
# 58 True
# 59 False.
# 60 False.
# 61 True
# 62 True
# 63 True
# 64 False
# 65 True
# 66 True
# 67 True
# 68 True
# 69 True
# 70 False
# 71 True
# 72 True
# 73 True
# 74 True
# 75 True
# 76 False
# 77 False
# 78 False
# 79 False
# 80 False
# 81 True
# 82 False
# 83 False
# 84 False
# 85 True
# 86 False
# 87 False
# 88 False.
# 89 True
# 90 False
# 91 False
# 92 False
# 93 False
# 94 True
# 95 True
# 96 False
# 97 True
# 98 False
# 99 False
# 100 False
# 101 False
# 102 False
# 103 False
# 104 False
# 105 False
# 106 False
# 107 False
# 108 False
# 109 True
# 110 False
# 111 True
# 112 True
# 113 False
# 114 True
# 115 False
# 116 True
# 117 False.
# 118 True
# 119 True
# 120 False.
# 121 False
# 122 True
# 123 False
# 124 True
# 125 True
# 126 False
# 127 True
# 128 False
# 129 True
# 130 False
# 131 True
# 132 True
# 133 False.
# 134 False.
# 135 False
# 136 True
# 137 False.
# 138 False
# 139 False.
# 140 True
# 141 True
# 142 False
# 143 False
# 144 False
# 145 False
# 146 False.
# 147 False
# 148 False.
# 149 False
# 150 False
# 151 False
# 152 False
# 153 False
# 154 False
# 155 False.
# 156 False
# 157 False
# 158 False
# 159 False
# 160 False
# 161 False
# 162 False
# 163 True
# 164 False
# 165 False
# 166 True
# 167 True
# 168 False
# 169 False
# 170 True
# 171 False
# 172 False
# 173 False
# 174 False
# 175 False
# 176 True
# 177 True
# 178 True
# 179 False
# 180 True
# 181 True
# 182 True
# 183 False
# 184 False
# 185 False
# 186 False
# 187 False
# 188 False
# 189 False
# 190 True
# 191 True
# 192 True
# 193 False
# 194 False
# 195 False
# 196 False.
# 197 True
# 198 False.
# 199 True
# 200 False

# %% [markdown]
# EVALUATOR

# %%
Settings
# Out:
# _Settings(_llm=OpenAI(callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x776563a1a740>, system_prompt=None, messages_to_prompt=<function messages_to_prompt at 0x77657152d510>, completion_to_prompt=<function default_completion_to_prompt at 0x7765715c97e0>, output_parser=None, pydantic_program_mode=<PydanticProgramMode.DEFAULT: 'default'>, query_wrapper_prompt=None, model='gpt-3.5-turbo', temperature=0.1, max_tokens=None, logprobs=None, top_logprobs=0, additional_kwargs={}, max_retries=3, timeout=60.0, default_headers=None, reuse_client=True, api_key='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', api_base='https://api.openai.com/v1', api_version='', strict=False), _embed_model=OpenAIEmbedding(model_name='text-embedding-ada-002', embed_batch_size=100, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x776563a1a740>, num_workers=None, additional_kwargs={}, api_key='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', api_base='https://api.openai.com/v1', api_version='', max_retries=10, timeout=60.0, default_headers=None, reuse_client=True, dimensions=None), _callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x776563a1a740>, _tokenizer=None, _node_parser=SentenceSplitter(include_metadata=True, include_prev_next_rel=True, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x776563a1a740>, id_func=<function default_id_func at 0x77657140ab00>, chunk_size=128, chunk_overlap=50, separator=' ', paragraph_separator='\n\n\n', secondary_chunking_regex='[^,.;。？！]+[,.;。？！]?'), _prompt_helper=None, _transformations=[SentenceSplitter(include_metadata=True, include_prev_next_rel=True, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x776563a1a740>, id_func=<function default_id_func at 0x77657140ab00>, chunk_size=128, chunk_overlap=50, separator=' ', paragraph_separator='\n\n\n', secondary_chunking_regex='[^,.;。？！]+[,.;。？！]?')])

# %%
eval_a_data = SimpleDirectoryReader("/mnt/disk1/sjw/llama_index/eval-a").load_data()

# %%
a_data = eval_a_data[0].text

answers = [line.strip().strip('"') for line in a_data.split('\n') if line.strip()]

# %%
responses_str = []

# %%
for response in responses:
    response_str = str(response)
    if "True" in response_str:
        response_str = "True"
    elif "False" in response_str:
        response_str = "False"
    
    responses_str.append(response_str)

# %%
correct_count=0
number=0

for answer, response, response_str, question in zip(answers, responses, responses_str, questions,):
    number+=1

    if answer == response_str:
        correct_count += 1
    else: 
        print("<<wrong>>\n", number, question)
        print("RESPONSE", response)
        print("CORRECT ANSWER", answer)
        print()
print(f"correct_count: {correct_count}")
# Out:
# <<wrong>>
#  7 True or False: Humanity's understanding of three-dimensional space limited the potential for technological innovations before the discovery of the fourth dimension.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  10 True or False: The discovery of exotic matter with negative mass is a direct result of fourth-dimensional research.
# RESPONSE False.
# CORRECT ANSWER True
#
# <<wrong>>
#  23 True or False: Human genetic modifications are necessary for extracting oxygen from a liquid atmosphere due to fourth-dimensional advancements.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  37 True or False: The new breathable liquid atmosphere will increase the friction in oxygen delivery.
# RESPONSE True
# CORRECT ANSWER False
#
# <<wrong>>
#  64 True or False: Advanced nanotechnology is essential for maintaining the proper oxygen levels in Earth's liquid atmosphere.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  70 True or False: Researchers have successfully altered atomic bonds to convert gases into a breathable liquid.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  71 True or False: Aquatic organisms need extensive changes to thrive in the newly created liquid atmosphere.
# RESPONSE True
# CORRECT ANSWER False
#
# <<wrong>>
#  74 True or False: The space station derives its energy from the neutron star using advanced fusion technology.
# RESPONSE True
# CORRECT ANSWER False
#
# <<wrong>>
#  76 True or False: The Johnson family’s adoption of Whiskers directly led to the first reported paranormal activity in Pinewood Hills.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  78 True or False: Whiskers’ ability to pass through walls was first observed after the Johnsons moved into their Victorian home.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  79 True or False: The increase in tourism to Pinewood Hills was a direct result of the combined phenomena of Whiskers and Arietta.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  84 True or False: Whiskers was responsible for the first occurrence of a time loop in Pinewood Hills.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  86 True or False: The Pinewood Hills Paranormal and Musical Phenomena Festival was held as a result of the mysterious abilities of both Whiskers and Arietta.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  92 True or False: The Johnsons decided to contact Dr. Martin Graves after Whiskers started disappearing through walls.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  102 True or False: The town of Pinewood Hills hosted its first-ever paranormal festival as a direct result of Whiskers’ ghostly appearances.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  112 True or False: Arietta’s ability to sing opera was discovered by accident when Timmy Watson was recording the sounds of the lake.
# RESPONSE True
# CORRECT ANSWER False
#
# <<wrong>>
#  114 True or False: The town of Pinewood Hills had a history of paranormal events before the arrival of Whiskers and Arietta.
# RESPONSE True
# CORRECT ANSWER False
#
# <<wrong>>
#  128 True or False: Only Whiskers and Arietta were unaffected by the time loop.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  133 True or False: The Pinewood Hills Institute for Extraordinary Phenomena (PHIEP) was established to study Whiskers and Arietta.
# RESPONSE False.
# CORRECT ANSWER True
#
# <<wrong>>
#  145 True or False: Arietta’s singing could be heard across the frozen waters of Pinewood Lake during the time loop incident.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  148 True or False: The Johnson family was initially unaware that Whiskers had supernatural abilities.
# RESPONSE False.
# CORRECT ANSWER True
#
# <<wrong>>
#  149 True or False: Whiskers was known to interact with other ghostly animals in Pinewood Hills.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  156 True or False: Pinewood Hills' economy improved significantly due to the influx of tourists attracted by Whiskers and Arietta.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  158 True or False: The Watson family initially tried to keep Arietta a secret from the public.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  159 True or False: Local schoolchildren wrote essays about the phenomena in Pinewood Hills as part of their curriculum.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  162 True or False: Pinewood Hills had to expand its infrastructure to accommodate the increased number of visitors.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  164 True or False: Whiskers once disappeared for an entire day, leaving the Johnson family very worried.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  167 True or False: The town’s clock tower was the only clock in Pinewood Hills unaffected by the time loop.
# RESPONSE True
# CORRECT ANSWER False
#
# <<wrong>>
#  170 True or False: Arietta was once observed to change the lyrics of a song to mimic human speech.
# RESPONSE True
# CORRECT ANSWER False
#
# <<wrong>>
#  172 True or False: Dr. Evelyn Tran suggested that Whiskers and Arietta might be connected through a quantum entanglement.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  175 True or False: Arietta's singing had a soothing effect on anyone who listened, even from a distance.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  182 True or False: The concept of building a space station around a neutron star was inspired by the discovery of a fourth spatial dimension.
# RESPONSE True
# CORRECT ANSWER False
#
# <<wrong>>
#  189 True or False: The fourth-dimensional technology could potentially allow scientists to manipulate time as well as space.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  191 True or False: The new liquid atmosphere will eliminate the need for traditional farming methods.
# RESPONSE True
# CORRECT ANSWER False
#
# <<wrong>>
#  193 True or False: The discovery of a fourth spatial dimension has led to new artistic movements and expressions.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  195 True or False: Arietta's songs were believed to have the power to calm storms around Pinewood Lake.
# RESPONSE False
# CORRECT ANSWER True
#
# correct_count: 164

# %%
accuracy = (correct_count / len(questions)) * 100
print(f"Total Questions: {len(questions)}")
print(f"Correct Answers: {correct_count}")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# Total Questions: 200
# Correct Answers: 164
# Accuracy: 82.00%

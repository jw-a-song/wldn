# %% [markdown]
# RETRIEVER

# %%
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader,get_response_synthesizer
from llama_index.core import SimpleDirectoryReader
from llama_index.core import Settings

Settings.chunk_size = 1024
Settings.chunk_overlap = 250

documents = SimpleDirectoryReader("/mnt/disk1/sjw/llama_index/data").load_data()
index = VectorStoreIndex.from_documents(documents)
retriever = index.as_retriever(verbose=True, similarity_top_k=2)
response_synthesizer = get_response_synthesizer(
    response_mode="compact",
)
query_engine = index.as_query_engine()

# %%
eval_q_data = SimpleDirectoryReader("/mnt/disk1/sjw/llama_index/eval-q").load_data()

# %%
q_data = eval_q_data[0].text

questions = [line.strip().strip('"') for line in q_data.split('\n') if line.strip()]

# %%
retriever_result = {}
search_results = []

for count, question in enumerate(questions, start=1):
    search_this = f"{question}"
    search_result = retriever.retrieve(search_this)
    search_results = []
    
    for i in range(retriever.similarity_top_k):
        search_results.append(search_result[i].get_text())

    retriever_result[count] = search_results

# %% [markdown]
# EMBEDDING MODEL

# %% [markdown]
# GENERATOR

# %%
from llama_index.core import VectorStoreIndex

vector_index = VectorStoreIndex.from_documents(documents)

# %%
responses=[]

# %%
for count, question in enumerate(questions, start=1):
    retriever_context_list = retriever_result.get(count, [])
    retriever_context = ' '.join(retriever_context_list)
    
    query = f"Given the context: '{retriever_context}', determine if the following statement is 'True' or 'False': {question}. Start your response with 'True' or 'False'. Answer:"

    # It's better to create the query engine once outside the loop if it doesn't need to be recreated each time
    query_engine = index.as_query_engine()
    response = query_engine.query(query)

    # Assuming response has a 'text' attribute that contains the response as a string
    response_text = response.text if hasattr(response, 'text') else str(response)

    # Find the position of "Answer:" and extract the response
    #aa = response_text.find("Answer:")
    #if aa != -1:
     #   response = response_text[aa + 7:].strip().split()[0]  # Extract the first word after "Answer:"

    responses.append(response)

    print(count, response)
# Out:
# 1 True
# 2 False
# 3 True
# 4 True
# 5 False.
# 6 True
# 7 True
# 8 True
# 9 False
# 10 False.
# 11 False.
# 12 True
# 13 False.
# 14 True
# 15 False
# 16 True
# 17 False
# 18 True
# 19 False
# 20 True
# 21 False
# 22 True
# 23 False
# 24 False
# 25 True
# 26 False
# 27 True
# 28 False
# 29 False
# 30 True
# 31 False.
# 32 False
# 33 False
# 34 False
# 35 True
# 36 True
# 37 False
# 38 False
# 39 True
# 40 False
# 41 False
# 42 False
# 43 False
# 44 True
# 45 True
# 46 False
# 47 True
# 48 False.
# 49 True
# 50 False
# 51 True
# 52 False
# 53 False.
# 54 True
# 55 False
# 56 True
# 57 False.
# 58 True
# 59 False
# 60 True
# 61 False
# 62 True
# 63 True
# 64 True
# 65 True
# 66 True
# 67 True
# 68 False
# 69 False
# 70 True
# 71 True
# 72 False
# 73 True
# 74 False
# 75 False
# 76 False
# 77 False
# 78 False
# 79 False
# 80 False
# 81 True
# 82 False
# 83 False
# 84 False
# 85 True
# 86 False
# 87 False
# 88 False
# 89 False
# 90 False
# 91 False
# 92 False
# 93 False
# 94 True
# 95 True
# 96 False.
# 97 True
# 98 False
# 99 False
# 100 False
# 101 False
# 102 False
# 103 False.
# 104 False
# 105 False
# 106 False
# 107 False
# 108 False
# 109 False
# 110 False
# 111 True
# 112 False
# 113 False
# 114 False
# 115 False
# 116 False.
# 117 False
# 118 True
# 119 False
# 120 False
# 121 False.
# 122 False
# 123 False
# 124 True
# 125 True
# 126 False
# 127 True
# 128 False
# 129 True
# 130 False
# 131 True
# 132 True
# 133 False
# 134 False
# 135 False
# 136 True
# 137 False
# 138 False
# 139 False
# 140 True
# 141 True
# 142 False
# 143 False
# 144 False
# 145 True
# 146 False
# 147 False
# 148 False.
# 149 False
# 150 False
# 151 False.
# 152 False
# 153 False
# 154 False
# 155 False
# 156 False
# 157 False.
# 158 False.
# 159 False
# 160 False
# 161 False.
# 162 True.
# 163 True
# 164 False
# 165 False.
# 166 True
# 167 False
# 168 False
# 169 False.
# 170 False
# 171 False
# 172 False
# 173 False
# 174 False.
# 175 False
# 176 True
# 177 True
# 178 True
# 179 False
# 180 True
# 181 False
# 182 False
# 183 False
# 184 False
# 185 False.
# 186 False.
# 187 False
# 188 False
# 189 True
# 190 True
# 191 False
# 192 True
# 193 False
# 194 False.
# 195 False
# 196 False: The space station near the neutron star would require new governance models and social structures to adapt to the confined and controlled environment, ensuring harmony and productivity within the station.
# 197 True
# 198 False.
# 199 True
# 200 False.

# %% [markdown]
# EVALUATOR

# %%
eval_a_data = SimpleDirectoryReader("/mnt/disk1/sjw/llama_index/eval-a").load_data()

# %%
a_data = eval_a_data[0].text

answers = [line.strip().strip('"') for line in a_data.split('\n') if line.strip()]

# %%
responses_str = []

# %%
for response in responses:
    response_str = str(response)
    if "True" in response_str:
        response_str = "True"
    elif "False" in response_str:
        response_str = "False"
    
    responses_str.append(response_str)

# %%
correct_count=0
number=0

for answer, response, response_str, question in zip(answers, responses, responses_str, questions,):
    number+=1

    if answer == response_str:
        correct_count += 1
    else: 
        print("<<wrong>>\n", number, question)
        print("RESPONSE", response)
        print("CORRECT ANSWER", answer)
        print()
print(f"correct_count: {correct_count}")
# Out:
# <<wrong>>
#  4 True or False: The fourth dimension is a temporal axis that affects the flow of time.
# RESPONSE True
# CORRECT ANSWER False
#
# <<wrong>>
#  5 True or False: Scientists plan to use particle colliders to manipulate the fourth dimension.
# RESPONSE False.
# CORRECT ANSWER True
#
# <<wrong>>
#  10 True or False: The discovery of exotic matter with negative mass is a direct result of fourth-dimensional research.
# RESPONSE False.
# CORRECT ANSWER True
#
# <<wrong>>
#  23 True or False: Human genetic modifications are necessary for extracting oxygen from a liquid atmosphere due to fourth-dimensional advancements.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  29 True or False: Harnessing energy from a neutron star is a solution for powering a space station.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  32 True or False: Fourth-dimensional technology will have significant geopolitical implications due to its potential.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  33 True or False: New alliances and conflicts may arise as a result of the advancements in fourth-dimensional technology.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  41 True or False: Nanotechnology can be used to enhance overall health and longevity in a liquid atmosphere.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  55 True or False: Energy harnessed from the neutron star could power the space station's operations.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  60 True or False: The identification of a fourth spatial dimension has enabled the development of a breathable liquid atmosphere on Earth.
# RESPONSE True
# CORRECT ANSWER False
#
# <<wrong>>
#  61 True or False: The space station orbiting the neutron star uses state-of-the-art fusion reactors for its energy needs.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  68 True or False: The space station derives its energy from the neutron star using advanced fusion technology.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  69 True or False: Discoveries in fourth-dimensional technology have altered global political power structures.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  71 True or False: Aquatic organisms need extensive changes to thrive in the newly created liquid atmosphere.
# RESPONSE True
# CORRECT ANSWER False
#
# <<wrong>>
#  72 True or False: The space station orbiting the neutron star uses state-of-the-art fusion reactors for its energy needs.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  75 True or False: Discoveries in fourth-dimensional technology have altered global political power structures.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  76 True or False: The Johnson family’s adoption of Whiskers directly led to the first reported paranormal activity in Pinewood Hills.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  78 True or False: Whiskers’ ability to pass through walls was first observed after the Johnsons moved into their Victorian home.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  79 True or False: The increase in tourism to Pinewood Hills was a direct result of the combined phenomena of Whiskers and Arietta.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  84 True or False: Whiskers was responsible for the first occurrence of a time loop in Pinewood Hills.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  86 True or False: The Pinewood Hills Paranormal and Musical Phenomena Festival was held as a result of the mysterious abilities of both Whiskers and Arietta.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  89 True or False: The town of Pinewood Hills would have remained unknown if not for the appearance of Whiskers and Arietta.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  92 True or False: The Johnsons decided to contact Dr. Martin Graves after Whiskers started disappearing through walls.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  102 True or False: The town of Pinewood Hills hosted its first-ever paranormal festival as a direct result of Whiskers’ ghostly appearances.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  109 True or False: Whiskers and Arietta were responsible for the sudden surge of interest in paranormal studies worldwide.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  116 True or False: The Johnson family adopted a kitten named Whiskers from a local shelter.
# RESPONSE False.
# CORRECT ANSWER True
#
# <<wrong>>
#  119 True or False: Arietta, the singing fish, was discovered by young Timmy Watson while fishing in Pinewood Lake.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  122 True or False: The town of Pinewood Hills hosted its first-ever Paranormal and Musical Phenomena Festival.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  128 True or False: Only Whiskers and Arietta were unaffected by the time loop.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  133 True or False: The Pinewood Hills Institute for Extraordinary Phenomena (PHIEP) was established to study Whiskers and Arietta.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  148 True or False: The Johnson family was initially unaware that Whiskers had supernatural abilities.
# RESPONSE False.
# CORRECT ANSWER True
#
# <<wrong>>
#  149 True or False: Whiskers was known to interact with other ghostly animals in Pinewood Hills.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  156 True or False: Pinewood Hills' economy improved significantly due to the influx of tourists attracted by Whiskers and Arietta.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  158 True or False: The Watson family initially tried to keep Arietta a secret from the public.
# RESPONSE False.
# CORRECT ANSWER True
#
# <<wrong>>
#  159 True or False: Local schoolchildren wrote essays about the phenomena in Pinewood Hills as part of their curriculum.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  164 True or False: Whiskers once disappeared for an entire day, leaving the Johnson family very worried.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  172 True or False: Dr. Evelyn Tran suggested that Whiskers and Arietta might be connected through a quantum entanglement.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  175 True or False: Arietta's singing had a soothing effect on anyone who listened, even from a distance.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  181 True or False: In a liquid atmosphere, humans might develop new forms of communication adapted to the liquid environment.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  193 True or False: The discovery of a fourth spatial dimension has led to new artistic movements and expressions.
# RESPONSE False
# CORRECT ANSWER True
#
# <<wrong>>
#  195 True or False: Arietta's songs were believed to have the power to calm storms around Pinewood Lake.
# RESPONSE False
# CORRECT ANSWER True
#
# correct_count: 159

# %%
accuracy = (correct_count / len(questions)) * 100
print(f"Total Questions: {len(questions)}")
print(f"Correct Answers: {correct_count}")
print(f"Accuracy: {accuracy:.2f}%")
# Out:
# Total Questions: 200
# Correct Answers: 159
# Accuracy: 79.50%

# %%
Settings
# Out:
# _Settings(_llm=OpenAI(callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x74833272eaa0>, system_prompt=None, messages_to_prompt=<function messages_to_prompt at 0x748340bed120>, completion_to_prompt=<function default_completion_to_prompt at 0x748340a913f0>, output_parser=None, pydantic_program_mode=<PydanticProgramMode.DEFAULT: 'default'>, query_wrapper_prompt=None, model='gpt-3.5-turbo', temperature=0.1, max_tokens=None, logprobs=None, top_logprobs=0, additional_kwargs={}, max_retries=3, timeout=60.0, default_headers=None, reuse_client=True, api_key='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', api_base='https://api.openai.com/v1', api_version='', strict=False), _embed_model=OpenAIEmbedding(model_name='text-embedding-ada-002', embed_batch_size=100, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x74833272eaa0>, num_workers=None, additional_kwargs={}, api_key='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', api_base='https://api.openai.com/v1', api_version='', max_retries=10, timeout=60.0, default_headers=None, reuse_client=True, dimensions=None), _callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x74833272eaa0>, _tokenizer=None, _node_parser=SentenceSplitter(include_metadata=True, include_prev_next_rel=True, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x74833272eaa0>, id_func=<function default_id_func at 0x748340aca710>, chunk_size=1024, chunk_overlap=250, separator=' ', paragraph_separator='\n\n\n', secondary_chunking_regex='[^,.;。？！]+[,.;。？！]?'), _prompt_helper=None, _transformations=[SentenceSplitter(include_metadata=True, include_prev_next_rel=True, callback_manager=<llama_index.core.callbacks.base.CallbackManager object at 0x74833272eaa0>, id_func=<function default_id_func at 0x748340aca710>, chunk_size=1024, chunk_overlap=250, separator=' ', paragraph_separator='\n\n\n', secondary_chunking_regex='[^,.;。？！]+[,.;。？！]?')])
